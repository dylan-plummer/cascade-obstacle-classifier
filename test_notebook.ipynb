# %%
import numpy as np
import os
import cv2
import time

classifier = cv2.CascadeClassifier('data/cascade.xml')

frames_dir = 'img/'
#frames_dir = 'kinect_data/'
directory = os.fsencode(frames_dir)
frame_i = 0

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".png"):
        file_path = frames_dir + filename
        print(file_path)
        img = cv2.imread(file_path)
        #img = np.load(file_path)
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        #gray = np.uint8(img)
        obstacles = classifier.detectMultiScale(gray, 1.3, 15)
        for (x,y,w,h) in obstacles:
            cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]

        cv2.imshow('img',img)
        key = cv2.waitKey(delay=1)qqqqqqq
        #time.sleep(1)
        if key == ord('q'):
            break
cv2.destroyAllWindows()
# Out:
# C:\Users\jumpr_000\Anaconda2\envs\py36\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: The Windows bytes API has been deprecated, use Unicode filenames instead
#   del sys.path[0]
# img/0001.png
# img/0002.png
# img/0003.png
# img/0004.png
# img/0005.png
# img/0006.png
# img/0007.png
# img/0008.png
# img/0009.png
# img/0010.png
# img/0011.png
# img/0012.png
# img/0013.png
# img/0014.png
# img/0015.png
# img/0016.png
# img/0017.png
# img/0018.png
# img/0019.png
# img/0020.png
# img/0021.png
# img/0022.png
# img/0023.png
# img/0024.png
# img/0025.png
# img/0026.png
# img/0027.png
# img/0028.png
# img/0029.png
# img/0030.png
# img/0031.png
# img/0032.png
# img/0033.png
# img/0034.png
# img/0035.png
# img/0036.png
# img/0037.png
# img/0038.png
# img/0039.png
# img/0040.png
# img/0041.png
# img/0042.png
# img/0043.png
# img/0044.png
# img/0045.png
# img/0046.png
# img/0047.png
# img/0048.png
# img/0049.png
# img/0050.png
# img/0051.png
# img/0052.png
# img/0053.png
# ...

# %%
import numpy as np
import os
import cv2
import time

classifier = cv2.CascadeClassifier('data/cascade.xml')

frames_dir = 'kinect_data/'
directory = os.fsencode(frames_dir)
frame_i = 0

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".npy"):
        file_path = frames_dir + filename
        print(file_path)
        img = np.load(file_path)
        gray = np.uint8(img)
        obstacles = classifier.detectMultiScale(gray, 1.3, 15)
        for (x,y,w,h) in obstacles:
            cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]

        cv2.imshow('img',img)
        cv2.imwrite(file_path + '.png',img)
        key = cv2.waitKey(delay=1)
        if key == ord('q'):
            break
cv2.destroyAllWindows()
